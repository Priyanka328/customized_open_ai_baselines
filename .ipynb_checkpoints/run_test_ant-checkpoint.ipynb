# %% [markdown]
# # Run tests with Ant

# %%
# !python -m baselines.ddpg_custom.main --env-id Ant-v2 --nb-epochs 2000 --gamma 0.999 --nb-epoch-cycles 1 --nb-rollout-steps 10000 --seed 0
# Out:
# Logging to /tmp/openai-2018-09-11-02-20-06-016836
# Text name: ddpg_ant_seed0.txt
# /root/github/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Custom Ant Environment.
# Obs dim:[111] Act dim:[8] dt:[0.050]
#
#
#
#  rank:[0]
#
#
#
#
#
#
#  Evaluation.
#
#
#
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Custom Ant Environment.
# Obs dim:[111] Act dim:[8] dt:[0.050]
# noise_type: adaptive-param_0.1
# current_noise_type: adaptive-param_0.1
# rank 0: seed=0, logdir=/tmp/openai-2018-09-11-02-20-06-016836
# scaling actions by [1. 1. 1. 1. 1. 1. 1. 1.] before executing in env
#
#
#  actor_lr:0.0001 critic_lr:0.0001
#
#
# [DDPG] gamma:0.9990 tau:0.0010 actor_lr:0.0001 critic_lr:0.0001
# setting up param noise
#   param_noise_actor/dense/kernel:0 <- actor/dense/kernel:0 + noise
#   param_noise_actor/dense/bias:0 <- actor/dense/bias:0 + noise
#   param_noise_actor/LayerNorm/beta:0 <- actor/LayerNorm/beta:0
#   param_noise_actor/LayerNorm/gamma:0 <- actor/LayerNorm/gamma:0
#   param_noise_actor/dense_1/kernel:0 <- actor/dense_1/kernel:0 + noise
#   param_noise_actor/dense_1/bias:0 <- actor/dense_1/bias:0 + noise
#   param_noise_actor/LayerNorm_1/beta:0 <- actor/LayerNorm_1/beta:0
#   param_noise_actor/LayerNorm_1/gamma:0 <- actor/LayerNorm_1/gamma:0
#   param_noise_actor/dense_2/kernel:0 <- actor/dense_2/kernel:0 + noise
#   param_noise_actor/dense_2/bias:0 <- actor/dense_2/bias:0 + noise
#   adaptive_param_noise_actor/dense/kernel:0 <- actor/dense/kernel:0 + noise
#   adaptive_param_noise_actor/dense/bias:0 <- actor/dense/bias:0 + noise
#   adaptive_param_noise_actor/LayerNorm/beta:0 <- actor/LayerNorm/beta:0
#   adaptive_param_noise_actor/LayerNorm/gamma:0 <- actor/LayerNorm/gamma:0
#   adaptive_param_noise_actor/dense_1/kernel:0 <- actor/dense_1/kernel:0 + noise
#   adaptive_param_noise_actor/dense_1/bias:0 <- actor/dense_1/bias:0 + noise
#   adaptive_param_noise_actor/LayerNorm_1/beta:0 <- actor/LayerNorm_1/beta:0
#   adaptive_param_noise_actor/LayerNorm_1/gamma:0 <- actor/LayerNorm_1/gamma:0
#   adaptive_param_noise_actor/dense_2/kernel:0 <- actor/dense_2/kernel:0 + noise
#   adaptive_param_noise_actor/dense_2/bias:0 <- actor/dense_2/bias:0 + noise
# setting up actor optimizer
#   actor shapes: [[111, 64], [64], [64], [64], [64, 64], [64], [64], [64], [64, 8], [8]]
#   actor params: 12104
# setting up critic optimizer
#   regularizing: critic/dense/kernel:0
#   regularizing: critic/dense_1/kernel:0
#   regularizing: critic/dense_2/kernel:0
#   applying l2 regularization with 0.01
#   critic shapes: [[111, 64], [64], [64], [64], [72, 64], [64], [64], [64], [64, 1], [1]]
#   critic params: 12161
# WARNING:tensorflow:From /root/github/customized_open_ai_baselines/baselines/ddpg_custom/ddpg.py:29: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# setting up target updates ...
#   target_actor/dense/kernel:0 <- actor/dense/kernel:0
#   target_actor/dense/bias:0 <- actor/dense/bias:0
#   target_actor/LayerNorm/beta:0 <- actor/LayerNorm/beta:0
#   target_actor/LayerNorm/gamma:0 <- actor/LayerNorm/gamma:0
#   target_actor/dense_1/kernel:0 <- actor/dense_1/kernel:0
#   target_actor/dense_1/bias:0 <- actor/dense_1/bias:0
#   target_actor/LayerNorm_1/beta:0 <- actor/LayerNorm_1/beta:0
#   target_actor/LayerNorm_1/gamma:0 <- actor/LayerNorm_1/gamma:0
#   target_actor/dense_2/kernel:0 <- actor/dense_2/kernel:0
#   target_actor/dense_2/bias:0 <- actor/dense_2/bias:0
# setting up target updates ...
#   target_critic/dense/kernel:0 <- critic/dense/kernel:0
#   target_critic/dense/bias:0 <- critic/dense/bias:0
#   target_critic/LayerNorm/beta:0 <- critic/LayerNorm/beta:0
#   target_critic/LayerNorm/gamma:0 <- critic/LayerNorm/gamma:0
#   target_critic/dense_1/kernel:0 <- critic/dense_1/kernel:0
#   target_critic/dense_1/bias:0 <- critic/dense_1/bias:0
#   target_critic/LayerNorm_1/beta:0 <- critic/LayerNorm_1/beta:0
#   target_critic/LayerNorm_1/gamma:0 <- critic/LayerNorm_1/gamma:0
#   target_critic/dense_2/kernel:0 <- critic/dense_2/kernel:0
#   target_critic/dense_2/bias:0 <- critic/dense_2/bias:0
# Using agent with the following configuration:
# dict_items([('actions', <tf.Tensor 'actions:0' shape=(?, 8) dtype=float32>), ('critic_target', <tf.Tensor 'critic_target:0' shape=(?, 1) dtype=float32>), ('obs0', <tf.Tensor 'obs0:0' shape=(?, 111) dtype=float32>), ('target_soft_updates', [<tf.Operation 'group_deps_5' type=NoOp>, <tf.Operation 'group_deps_7' type=NoOp>]), ('target_Q', <tf.Tensor 'add:0' shape=(?, 1) dtype=float32>), ('action_noise', None), ('param_noise_stddev', <tf.Tensor 'param_noise_stddev:0' shape=() dtype=float32>), ('normalize_returns', False), ('return_range', (-inf, inf)), ('stats_names', ['obs_rms_mean', 'obs_rms_std', 'reference_Q_mean', 'reference_Q_std', 'reference_actor_Q_mean', 'reference_actor_Q_std', 'reference_action_mean', 'reference_action_std', 'reference_perturbed_action_mean', 'reference_perturbed_action_std']), ('normalize_observations', True), ('actor_lr', 0.0001), ('perturbed_actor_tf', <tf.Tensor 'param_noise_actor/Tanh:0' shape=(?, 8) dtype=float32>), ('critic_loss', <tf.Tensor 'add_13:0' shape=() dtype=float32>), ('target_critic', <baselines.ddpg_custom.models.Critic object at 0x7f15ef5fae48>), ('clip_norm', None), ('actor', <baselines.ddpg_custom.models.Actor object at 0x7f15ef5fac50>), ('memory', <baselines.ddpg_custom.memory.Memory object at 0x7f15ef5faa90>), ('critic_tf', <tf.Tensor 'clip_by_value_2:0' shape=(?, 1) dtype=float32>), ('target_init_updates', [<tf.Operation 'group_deps_4' type=NoOp>, <tf.Operation 'group_deps_6' type=NoOp>]), ('perturb_adaptive_policy_ops', <tf.Operation 'group_deps_1' type=NoOp>), ('obs1', <tf.Tensor 'obs1:0' shape=(?, 111) dtype=float32>), ('batch_size', 64), ('critic_lr', 0.0001), ('rewards', <tf.Tensor 'rewards:0' shape=(?, 1) dtype=float32>), ('tau', 0.001), ('reward_scale', 1.0), ('critic_l2_reg', 0.01), ('actor_grads', <tf.Tensor 'concat:0' shape=(12104,) dtype=float32>), ('critic_grads', <tf.Tensor 'concat_2:0' shape=(12161,) dtype=float32>), ('actor_tf', <tf.Tensor 'actor/Tanh:0' shape=(?, 8) dtype=float32>), ('actor_loss', <tf.Tensor 'Neg:0' shape=() dtype=float32>), ('terminals1', <tf.Tensor 'terminals1:0' shape=(?, 1) dtype=float32>), ('obs_rms', <baselines.common.mpi_running_mean_std.RunningMeanStd object at 0x7f15ece4b6d8>), ('normalized_critic_tf', <tf.Tensor 'critic/dense_2/BiasAdd:0' shape=(?, 1) dtype=float32>), ('stats_sample', None), ('stats_ops', [<tf.Tensor 'Mean_3:0' shape=() dtype=float32>, <tf.Tensor 'Mean_4:0' shape=() dtype=float32>, <tf.Tensor 'Mean_5:0' shape=() dtype=float32>, <tf.Tensor 'Sqrt_1:0' shape=() dtype=float32>, <tf.Tensor 'Mean_8:0' shape=() dtype=float32>, <tf.Tensor 'Sqrt_2:0' shape=() dtype=float32>, <tf.Tensor 'Mean_11:0' shape=() dtype=float32>, <tf.Tensor 'Sqrt_3:0' shape=() dtype=float32>, <tf.Tensor 'Mean_14:0' shape=() dtype=float32>, <tf.Tensor 'Sqrt_4:0' shape=() dtype=float32>]), ('observation_range', (-5.0, 5.0)), ('critic_with_actor_tf', <tf.Tensor 'clip_by_value_3:0' shape=(?, 1) dtype=float32>), ('actor_optimizer', <baselines.common.mpi_adam.MpiAdam object at 0x7f15e7ec0748>), ('action_range', (-1.0, 1.0)), ('ret_rms', None), ('perturb_policy_ops', <tf.Operation 'group_deps' type=NoOp>), ('param_noise', AdaptiveParamNoiseSpec(initial_stddev=0.1, desired_action_stddev=0.1, adoption_coefficient=1.01)), ('enable_popart', False), ('target_actor', <baselines.ddpg_custom.models.Actor object at 0x7f15ef5faeb8>), ('adaptive_policy_distance', <tf.Tensor 'Sqrt:0' shape=() dtype=float32>), ('normalized_critic_with_actor_tf', <tf.Tensor 'critic_1/dense_2/BiasAdd:0' shape=(?, 1) dtype=float32>), ('critic', <baselines.ddpg_custom.models.Critic object at 0x7f15ef5fac18>), ('critic_optimizer', <baselines.common.mpi_adam.MpiAdam object at 0x7f15e56e8f98>), ('gamma', 0.999)])
# 2018-09-11 02:20:08.835303: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2018-09-11 02:20:09.237735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla P40 major: 6 minor: 1 memoryClockRate(GHz): 1.531
# pciBusID: 0000:08:00.0
# totalMemory: 22.38GiB freeMemory: 21.75GiB
# 2018-09-11 02:20:09.237817: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1435] Adding visible gpu devices: 0
# 2018-09-11 02:20:09.621947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:923] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-09-11 02:20:09.622025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:929]      0
# 2018-09-11 02:20:09.622042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:942] 0:   N
# 2018-09-11 02:20:09.622525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1053] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 21103 MB memory) -> physical GPU (device: 0, name: Tesla P40, pci bus id: 0000:08:00.0, compute capability: 6.1)
# [0/2000] rSumAvg:[95.303]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 95.3     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0215   |
# | obs_rms_std             | 0.377    |
# | param_noise_stddev      | 0.099    |
# | reference_Q_mean        | 0.14     |
# | reference_Q_std         | 0.0101   |
# | reference_action_mean   | -0.0167  |
# | reference_action_std    | 0.125    |
# | reference_actor_Q_mean  | 0.142    |
# | reference_actor_Q_std   | 0.0104   |
# | reference_perturbed_... | 0.514    |
# | rollout/Q_mean          | 0.00782  |
# | rollout/actions_mean    | 0.00819  |
# | rollout/actions_std     | 0.458    |
# | rollout/episode_steps   | 96.8     |
# | rollout/episodes        | 103      |
# | rollout/return          | 61.3     |
# | rollout/return_history  | 60.9     |
# | total/duration          | 30.3     |
# | total/episodes          | 103      |
# | total/epochs            | 1        |
# | total/steps             | 10000    |
# | total/steps_per_second  | 330      |
# | train/loss_actor        | -0.0738  |
# | train/loss_critic       | 1.37     |
# | train/param_noise_di... | 0.414    |
# --------------------------------------
#
# [1/2000] rSumAvg:[91.710]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 91.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0223   |
# | obs_rms_std             | 0.372    |
# | param_noise_stddev      | 0.098    |
# | reference_Q_mean        | 0.271    |
# | reference_Q_std         | 0.0142   |
# | reference_action_mean   | -0.0336  |
# | reference_action_std    | 0.25     |
# | reference_actor_Q_mean  | 0.274    |
# | reference_actor_Q_std   | 0.0145   |
# | reference_perturbed_... | 0.509    |
# | rollout/Q_mean          | 0.0735   |
# | rollout/actions_mean    | 0.000438 |
# | rollout/actions_std     | 0.466    |
# | rollout/episode_steps   | 97.9     |
# | rollout/episodes        | 204      |
# | rollout/return          | 66.2     |
# | rollout/return_history  | 71.5     |
# | total/duration          | 58.9     |
# | total/episodes          | 204      |
# | total/epochs            | 2        |
# | total/steps             | 20000    |
# | total/steps_per_second  | 340      |
# | train/loss_actor        | -0.205   |
# | train/loss_critic       | 1.18     |
# | train/param_noise_di... | 0.483    |
# --------------------------------------
#
# [2/2000] rSumAvg:[86.567]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 86.6     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0224   |
# | obs_rms_std             | 0.366    |
# | param_noise_stddev      | 0.0971   |
# | reference_Q_mean        | 0.392    |
# | reference_Q_std         | 0.0191   |
# | reference_action_mean   | -0.0659  |
# | reference_action_std    | 0.372    |
# | reference_actor_Q_mean  | 0.398    |
# | reference_actor_Q_std   | 0.0191   |
# | reference_perturbed_... | 0.46     |
# | rollout/Q_mean          | 0.14     |
# | rollout/actions_mean    | -0.0109  |
# | rollout/actions_std     | 0.474    |
# | rollout/episode_steps   | 98.3     |
# | rollout/episodes        | 305      |
# | rollout/return          | 65.7     |
# | rollout/return_history  | 64.7     |
# | total/duration          | 87.4     |
# | total/episodes          | 305      |
# | total/epochs            | 3        |
# | total/steps             | 30000    |
# | total/steps_per_second  | 343      |
# | train/loss_actor        | -0.335   |
# | train/loss_critic       | 1.01     |
# | train/param_noise_di... | 0.379    |
# --------------------------------------
#
# [3/2000] rSumAvg:[75.160]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 75.2     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0227   |
# | obs_rms_std             | 0.36     |
# | param_noise_stddev      | 0.0961   |
# | reference_Q_mean        | 0.502    |
# | reference_Q_std         | 0.0243   |
# | reference_action_mean   | -0.102   |
# | reference_action_std    | 0.488    |
# | reference_actor_Q_mean  | 0.511    |
# | reference_actor_Q_std   | 0.0231   |
# | reference_perturbed_... | 0.546    |
# | rollout/Q_mean          | 0.203    |
# | rollout/actions_mean    | -0.0248  |
# | rollout/actions_std     | 0.488    |
# | rollout/episode_steps   | 99       |
# | rollout/episodes        | 404      |
# | rollout/return          | 66.4     |
# | rollout/return_history  | 68.7     |
# | total/duration          | 117      |
# | total/episodes          | 404      |
# | total/epochs            | 4        |
# | total/steps             | 40000    |
# | total/steps_per_second  | 343      |
# | train/loss_actor        | -0.453   |
# | train/loss_critic       | 0.862    |
# | train/param_noise_di... | 0.384    |
# --------------------------------------
#
# [4/2000] rSumAvg:[65.910]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 65.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0238   |
# | obs_rms_std             | 0.352    |
# | param_noise_stddev      | 0.0951   |
# | reference_Q_mean        | 0.589    |
# | reference_Q_std         | 0.0301   |
# | reference_action_mean   | -0.132   |
# | reference_action_std    | 0.58     |
# | reference_actor_Q_mean  | 0.602    |
# | reference_actor_Q_std   | 0.0278   |
# | reference_perturbed_... | 0.445    |
# | rollout/Q_mean          | 0.265    |
# | rollout/actions_mean    | -0.0355  |
# | rollout/actions_std     | 0.506    |
# | rollout/episode_steps   | 99.4     |
# | rollout/episodes        | 503      |
# | rollout/return          | 66.6     |
# | rollout/return_history  | 67.4     |
# | total/duration          | 145      |
# | total/episodes          | 503      |
# | total/epochs            | 5        |
# | total/steps             | 50000    |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -0.559   |
# | train/loss_critic       | 0.762    |
# | train/param_noise_di... | 0.5      |
# --------------------------------------
#
# [5/2000] rSumAvg:[57.681]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 57.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0245   |
# | obs_rms_std             | 0.344    |
# | param_noise_stddev      | 0.0942   |
# | reference_Q_mean        | 0.661    |
# | reference_Q_std         | 0.0369   |
# | reference_action_mean   | -0.148   |
# | reference_action_std    | 0.655    |
# | reference_actor_Q_mean  | 0.679    |
# | reference_actor_Q_std   | 0.0328   |
# | reference_perturbed_... | 0.68     |
# | rollout/Q_mean          | 0.322    |
# | rollout/actions_mean    | -0.0512  |
# | rollout/actions_std     | 0.523    |
# | rollout/episode_steps   | 99.6     |
# | rollout/episodes        | 602      |
# | rollout/return          | 66.4     |
# | rollout/return_history  | 65.4     |
# | total/duration          | 175      |
# | total/episodes          | 602      |
# | total/epochs            | 6        |
# | total/steps             | 60000    |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -0.644   |
# | train/loss_critic       | 0.689    |
# | train/param_noise_di... | 0.307    |
# --------------------------------------
# [6/2000] rSumAvg:[51.096]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 51.1     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0259   |
# | obs_rms_std             | 0.336    |
# | param_noise_stddev      | 0.0933   |
# | reference_Q_mean        | 0.711    |
# | reference_Q_std         | 0.0469   |
# | reference_action_mean   | -0.151   |
# | reference_action_std    | 0.709    |
# | reference_actor_Q_mean  | 0.733    |
# | reference_actor_Q_std   | 0.0406   |
# | reference_perturbed_... | 0.705    |
# | rollout/Q_mean          | 0.374    |
# | rollout/actions_mean    | -0.0649  |
# | rollout/actions_std     | 0.545    |
# | rollout/episode_steps   | 99.8     |
# | rollout/episodes        | 701      |
# | rollout/return          | 65.5     |
# | rollout/return_history  | 60.3     |
# | total/duration          | 203      |
# | total/episodes          | 701      |
# | total/epochs            | 7        |
# | total/steps             | 70000    |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -0.709   |
# | train/loss_critic       | 0.626    |
# | train/param_noise_di... | 0.285    |
# --------------------------------------
#
# [7/2000] rSumAvg:[46.851]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 46.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0272   |
# | obs_rms_std             | 0.328    |
# | param_noise_stddev      | 0.0923   |
# | reference_Q_mean        | 0.743    |
# | reference_Q_std         | 0.0593   |
# | reference_action_mean   | -0.142   |
# | reference_action_std    | 0.742    |
# | reference_actor_Q_mean  | 0.767    |
# | reference_actor_Q_std   | 0.0512   |
# | reference_perturbed_... | 0.621    |
# | rollout/Q_mean          | 0.419    |
# | rollout/actions_mean    | -0.0754  |
# | rollout/actions_std     | 0.565    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 800      |
# | rollout/return          | 64.3     |
# | rollout/return_history  | 55.4     |
# | total/duration          | 232      |
# | total/episodes          | 800      |
# | total/epochs            | 8        |
# | total/steps             | 80000    |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -0.755   |
# | train/loss_critic       | 0.552    |
# | train/param_noise_di... | 0.241    |
# --------------------------------------
#
# [8/2000] rSumAvg:[44.656]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 44.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0285   |
# | obs_rms_std             | 0.321    |
# | param_noise_stddev      | 0.0914   |
# | reference_Q_mean        | 0.758    |
# | reference_Q_std         | 0.0774   |
# | reference_action_mean   | -0.131   |
# | reference_action_std    | 0.764    |
# | reference_actor_Q_mean  | 0.784    |
# | reference_actor_Q_std   | 0.0674   |
# | reference_perturbed_... | 0.728    |
# | rollout/Q_mean          | 0.457    |
# | rollout/actions_mean    | -0.0823  |
# | rollout/actions_std     | 0.587    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 899      |
# | rollout/return          | 62.9     |
# | rollout/return_history  | 51.9     |
# | total/duration          | 261      |
# | total/episodes          | 899      |
# | total/epochs            | 9        |
# | total/steps             | 90000    |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.769   |
# | train/loss_critic       | 0.532    |
# | train/param_noise_di... | 0.466    |
# --------------------------------------
#
# [9/2000] rSumAvg:[43.695]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 43.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0293   |
# | obs_rms_std             | 0.314    |
# | param_noise_stddev      | 0.0905   |
# | reference_Q_mean        | 0.783    |
# | reference_Q_std         | 0.0991   |
# | reference_action_mean   | -0.121   |
# | reference_action_std    | 0.762    |
# | reference_actor_Q_mean  | 0.807    |
# | reference_actor_Q_std   | 0.0877   |
# | reference_perturbed_... | 0.822    |
# | rollout/Q_mean          | 0.488    |
# | rollout/actions_mean    | -0.0882  |
# | rollout/actions_std     | 0.605    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 998      |
# | rollout/return          | 61.4     |
# | rollout/return_history  | 48.1     |
# | total/duration          | 290      |
# | total/episodes          | 998      |
# | total/epochs            | 10       |
# | total/steps             | 100000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.785   |
# | train/loss_critic       | 0.482    |
# | train/param_noise_di... | 0.231    |
# --------------------------------------
#
# [10/2000] rSumAvg:[47.831]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 47.8     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.03     |
# | obs_rms_std             | 0.31     |
# | param_noise_stddev      | 0.0896   |
# | reference_Q_mean        | 0.812    |
# | reference_Q_std         | 0.124    |
# | reference_action_mean   | -0.114   |
# | reference_action_std    | 0.75     |
# | reference_actor_Q_mean  | 0.835    |
# | reference_actor_Q_std   | 0.112    |
# | reference_perturbed_... | 0.723    |
# | rollout/Q_mean          | 0.513    |
# | rollout/actions_mean    | -0.0934  |
# | rollout/actions_std     | 0.62     |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.1e+03  |
# | rollout/return          | 60.2     |
# | rollout/return_history  | 47.9     |
# | total/duration          | 319      |
# | total/episodes          | 1.1e+03  |
# | total/epochs            | 11       |
# | total/steps             | 110000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.795   |
# | train/loss_critic       | 0.446    |
# | train/param_noise_di... | 0.22     |
# --------------------------------------
#
# [11/2000] rSumAvg:[49.933]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 49.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0302   |
# | obs_rms_std             | 0.306    |
# | param_noise_stddev      | 0.0887   |
# | reference_Q_mean        | 0.833    |
# | reference_Q_std         | 0.154    |
# | reference_action_mean   | -0.122   |
# | reference_action_std    | 0.723    |
# | reference_actor_Q_mean  | 0.854    |
# | reference_actor_Q_std   | 0.141    |
# | reference_perturbed_... | 0.688    |
# | rollout/Q_mean          | 0.536    |
# | rollout/actions_mean    | -0.0972  |
# | rollout/actions_std     | 0.629    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.2e+03  |
# | rollout/return          | 59.4     |
# | rollout/return_history  | 50.6     |
# | total/duration          | 348      |
# | total/episodes          | 1.2e+03  |
# | total/epochs            | 12       |
# | total/steps             | 120000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.817   |
# | train/loss_critic       | 0.411    |
# | train/param_noise_di... | 0.332    |
# --------------------------------------
#
# [12/2000] rSumAvg:[50.246]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 50.2     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.03     |
# | obs_rms_std             | 0.305    |
# | param_noise_stddev      | 0.0879   |
# | reference_Q_mean        | 0.88     |
# | reference_Q_std         | 0.18     |
# | reference_action_mean   | -0.131   |
# | reference_action_std    | 0.691    |
# | reference_actor_Q_mean  | 0.897    |
# | reference_actor_Q_std   | 0.167    |
# | reference_perturbed_... | 0.795    |
# | rollout/Q_mean          | 0.557    |
# | rollout/actions_mean    | -0.101   |
# | rollout/actions_std     | 0.636    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.3e+03  |
# | rollout/return          | 58.9     |
# | rollout/return_history  | 52.8     |
# | total/duration          | 377      |
# | total/episodes          | 1.3e+03  |
# | total/epochs            | 13       |
# | total/steps             | 130000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.843   |
# | train/loss_critic       | 0.368    |
# | train/param_noise_di... | 0.31     |
# --------------------------------------
# [13/2000] rSumAvg:[63.463]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 63.5     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0297   |
# | obs_rms_std             | 0.306    |
# | param_noise_stddev      | 0.087    |
# | reference_Q_mean        | 0.893    |
# | reference_Q_std         | 0.209    |
# | reference_action_mean   | -0.162   |
# | reference_action_std    | 0.641    |
# | reference_actor_Q_mean  | 0.907    |
# | reference_actor_Q_std   | 0.198    |
# | reference_perturbed_... | 0.714    |
# | rollout/Q_mean          | 0.578    |
# | rollout/actions_mean    | -0.104   |
# | rollout/actions_std     | 0.64     |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.39e+03 |
# | rollout/return          | 58.5     |
# | rollout/return_history  | 52.3     |
# | total/duration          | 406      |
# | total/episodes          | 1.39e+03 |
# | total/epochs            | 14       |
# | total/steps             | 140000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.865   |
# | train/loss_critic       | 0.346    |
# | train/param_noise_di... | 0.403    |
# --------------------------------------
#
# [14/2000] rSumAvg:[70.108]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 70.1     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0291   |
# | obs_rms_std             | 0.307    |
# | param_noise_stddev      | 0.0861   |
# | reference_Q_mean        | 0.928    |
# | reference_Q_std         | 0.235    |
# | reference_action_mean   | -0.172   |
# | reference_action_std    | 0.566    |
# | reference_actor_Q_mean  | 0.937    |
# | reference_actor_Q_std   | 0.228    |
# | reference_perturbed_... | 0.693    |
# | rollout/Q_mean          | 0.596    |
# | rollout/actions_mean    | -0.108   |
# | rollout/actions_std     | 0.64     |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.49e+03 |
# | rollout/return          | 57.9     |
# | rollout/return_history  | 50.9     |
# | total/duration          | 435      |
# | total/episodes          | 1.49e+03 |
# | total/epochs            | 15       |
# | total/steps             | 150000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.884   |
# | train/loss_critic       | 0.323    |
# | train/param_noise_di... | 0.458    |
# --------------------------------------
#
# [15/2000] rSumAvg:[85.846]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 85.8     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0285   |
# | obs_rms_std             | 0.309    |
# | param_noise_stddev      | 0.0853   |
# | reference_Q_mean        | 0.945    |
# | reference_Q_std         | 0.268    |
# | reference_action_mean   | -0.163   |
# | reference_action_std    | 0.476    |
# | reference_actor_Q_mean  | 0.958    |
# | reference_actor_Q_std   | 0.262    |
# | reference_perturbed_... | 0.687    |
# | rollout/Q_mean          | 0.615    |
# | rollout/actions_mean    | -0.112   |
# | rollout/actions_std     | 0.638    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.59e+03 |
# | rollout/return          | 58       |
# | rollout/return_history  | 58.4     |
# | total/duration          | 464      |
# | total/episodes          | 1.59e+03 |
# | total/epochs            | 16       |
# | total/steps             | 160000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.917   |
# | train/loss_critic       | 0.31     |
# | train/param_noise_di... | 0.451    |
# --------------------------------------
#
# [16/2000] rSumAvg:[88.054]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 88.1     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0278   |
# | obs_rms_std             | 0.311    |
# | param_noise_stddev      | 0.0844   |
# | reference_Q_mean        | 0.995    |
# | reference_Q_std         | 0.287    |
# | reference_action_mean   | -0.126   |
# | reference_action_std    | 0.449    |
# | reference_actor_Q_mean  | 1.01     |
# | reference_actor_Q_std   | 0.28     |
# | reference_perturbed_... | 0.583    |
# | rollout/Q_mean          | 0.635    |
# | rollout/actions_mean    | -0.115   |
# | rollout/actions_std     | 0.634    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.69e+03 |
# | rollout/return          | 57.9     |
# | rollout/return_history  | 57.3     |
# | total/duration          | 493      |
# | total/episodes          | 1.69e+03 |
# | total/epochs            | 17       |
# | total/steps             | 170000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -0.954   |
# | train/loss_critic       | 0.282    |
# | train/param_noise_di... | 0.363    |
# --------------------------------------
#
# [17/2000] rSumAvg:[84.778]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 84.8     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0274   |
# | obs_rms_std             | 0.314    |
# | param_noise_stddev      | 0.0836   |
# | reference_Q_mean        | 1.01     |
# | reference_Q_std         | 0.325    |
# | reference_action_mean   | -0.0425  |
# | reference_action_std    | 0.471    |
# | reference_actor_Q_mean  | 1.03     |
# | reference_actor_Q_std   | 0.318    |
# | reference_perturbed_... | 0.531    |
# | rollout/Q_mean          | 0.661    |
# | rollout/actions_mean    | -0.115   |
# | rollout/actions_std     | 0.629    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 1.79e+03 |
# | rollout/return          | 58.5     |
# | rollout/return_history  | 68.8     |
# | total/duration          | 522      |
# | total/episodes          | 1.79e+03 |
# | total/epochs            | 18       |
# | total/steps             | 180000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -1       |
# | train/loss_critic       | 0.271    |
# | train/param_noise_di... | 0.498    |
# --------------------------------------
#
# [18/2000] rSumAvg:[77.550]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 77.5     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0272   |
# | obs_rms_std             | 0.316    |
# | param_noise_stddev      | 0.0828   |
# | reference_Q_mean        | 1.03     |
# | reference_Q_std         | 0.346    |
# | reference_action_mean   | -0.00886 |
# | reference_action_std    | 0.529    |
# | reference_actor_Q_mean  | 1.06     |
# | reference_actor_Q_std   | 0.334    |
# | reference_perturbed_... | 0.572    |
# | rollout/Q_mean          | 0.687    |
# | rollout/actions_mean    | -0.111   |
# | rollout/actions_std     | 0.625    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 1.89e+03 |
# | rollout/return          | 59.1     |
# | rollout/return_history  | 69.6     |
# | total/duration          | 551      |
# | total/episodes          | 1.89e+03 |
# | total/epochs            | 19       |
# | total/steps             | 190000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -1.04    |
# | train/loss_critic       | 0.254    |
# | train/param_noise_di... | 0.53     |
# --------------------------------------
#
# [19/2000] rSumAvg:[74.155]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 74.2     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0272   |
# | obs_rms_std             | 0.318    |
# | param_noise_stddev      | 0.082    |
# | reference_Q_mean        | 1.03     |
# | reference_Q_std         | 0.363    |
# | reference_action_mean   | 0.0511   |
# | reference_action_std    | 0.562    |
# | reference_actor_Q_mean  | 1.07     |
# | reference_actor_Q_std   | 0.348    |
# | reference_perturbed_... | 0.565    |
# | rollout/Q_mean          | 0.714    |
# | rollout/actions_mean    | -0.105   |
# | rollout/actions_std     | 0.624    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 1.99e+03 |
# | rollout/return          | 59.7     |
# | rollout/return_history  | 70.5     |
# | total/duration          | 580      |
# | total/episodes          | 1.99e+03 |
# | total/epochs            | 20       |
# | total/steps             | 200000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -1.07    |
# | train/loss_critic       | 0.237    |
# | train/param_noise_di... | 0.558    |
# --------------------------------------
# [20/2000] rSumAvg:[75.287]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 75.3     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0273   |
# | obs_rms_std             | 0.319    |
# | param_noise_stddev      | 0.0811   |
# | reference_Q_mean        | 1.05     |
# | reference_Q_std         | 0.38     |
# | reference_action_mean   | 0.0976   |
# | reference_action_std    | 0.572    |
# | reference_actor_Q_mean  | 1.09     |
# | reference_actor_Q_std   | 0.361    |
# | reference_perturbed_... | 0.587    |
# | rollout/Q_mean          | 0.737    |
# | rollout/actions_mean    | -0.0966  |
# | rollout/actions_std     | 0.624    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.09e+03 |
# | rollout/return          | 60.1     |
# | rollout/return_history  | 68.6     |
# | total/duration          | 609      |
# | total/episodes          | 2.09e+03 |
# | total/epochs            | 21       |
# | total/steps             | 210000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -1.12    |
# | train/loss_critic       | 0.225    |
# | train/param_noise_di... | 0.403    |
# --------------------------------------
#
# [21/2000] rSumAvg:[74.234]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 74.2     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0273   |
# | obs_rms_std             | 0.32     |
# | param_noise_stddev      | 0.0803   |
# | reference_Q_mean        | 1.06     |
# | reference_Q_std         | 0.394    |
# | reference_action_mean   | 0.0875   |
# | reference_action_std    | 0.618    |
# | reference_actor_Q_mean  | 1.11     |
# | reference_actor_Q_std   | 0.369    |
# | reference_perturbed_... | 0.687    |
# | rollout/Q_mean          | 0.759    |
# | rollout/actions_mean    | -0.0876  |
# | rollout/actions_std     | 0.624    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.19e+03 |
# | rollout/return          | 60.5     |
# | rollout/return_history  | 67.7     |
# | total/duration          | 639      |
# | total/episodes          | 2.19e+03 |
# | total/epochs            | 22       |
# | total/steps             | 220000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.14    |
# | train/loss_critic       | 0.211    |
# | train/param_noise_di... | 0.435    |
# --------------------------------------
#
# [22/2000] rSumAvg:[72.133]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 72.1     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0273   |
# | obs_rms_std             | 0.321    |
# | param_noise_stddev      | 0.0795   |
# | reference_Q_mean        | 1.09     |
# | reference_Q_std         | 0.409    |
# | reference_action_mean   | 0.074    |
# | reference_action_std    | 0.634    |
# | reference_actor_Q_mean  | 1.14     |
# | reference_actor_Q_std   | 0.378    |
# | reference_perturbed_... | 0.495    |
# | rollout/Q_mean          | 0.78     |
# | rollout/actions_mean    | -0.0792  |
# | rollout/actions_std     | 0.625    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.29e+03 |
# | rollout/return          | 60.7     |
# | rollout/return_history  | 65.9     |
# | total/duration          | 668      |
# | total/episodes          | 2.29e+03 |
# | total/epochs            | 23       |
# | total/steps             | 230000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.18    |
# | train/loss_critic       | 0.202    |
# | train/param_noise_di... | 0.395    |
# --------------------------------------
#
# [23/2000] rSumAvg:[59.673]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 59.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0273   |
# | obs_rms_std             | 0.322    |
# | param_noise_stddev      | 0.0788   |
# | reference_Q_mean        | 1.1      |
# | reference_Q_std         | 0.42     |
# | reference_action_mean   | 0.0911   |
# | reference_action_std    | 0.634    |
# | reference_actor_Q_mean  | 1.14     |
# | reference_actor_Q_std   | 0.388    |
# | reference_perturbed_... | 0.605    |
# | rollout/Q_mean          | 0.801    |
# | rollout/actions_mean    | -0.0709  |
# | rollout/actions_std     | 0.627    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.38e+03 |
# | rollout/return          | 60.9     |
# | rollout/return_history  | 65.5     |
# | total/duration          | 697      |
# | total/episodes          | 2.38e+03 |
# | total/epochs            | 24       |
# | total/steps             | 240000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.21    |
# | train/loss_critic       | 0.192    |
# | train/param_noise_di... | 0.31     |
# --------------------------------------
#
# [24/2000] rSumAvg:[64.502]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 64.5     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0272   |
# | obs_rms_std             | 0.324    |
# | param_noise_stddev      | 0.078    |
# | reference_Q_mean        | 1.11     |
# | reference_Q_std         | 0.441    |
# | reference_action_mean   | 0.101    |
# | reference_action_std    | 0.642    |
# | reference_actor_Q_mean  | 1.16     |
# | reference_actor_Q_std   | 0.405    |
# | reference_perturbed_... | 0.627    |
# | rollout/Q_mean          | 0.818    |
# | rollout/actions_mean    | -0.0642  |
# | rollout/actions_std     | 0.628    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.48e+03 |
# | rollout/return          | 60.9     |
# | rollout/return_history  | 61.8     |
# | total/duration          | 726      |
# | total/episodes          | 2.48e+03 |
# | total/epochs            | 25       |
# | total/steps             | 250000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.23    |
# | train/loss_critic       | 0.187    |
# | train/param_noise_di... | 0.405    |
# --------------------------------------
#
# [25/2000] rSumAvg:[59.727]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 59.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0271   |
# | obs_rms_std             | 0.325    |
# | param_noise_stddev      | 0.0772   |
# | reference_Q_mean        | 1.13     |
# | reference_Q_std         | 0.454    |
# | reference_action_mean   | 0.121    |
# | reference_action_std    | 0.65     |
# | reference_actor_Q_mean  | 1.18     |
# | reference_actor_Q_std   | 0.411    |
# | reference_perturbed_... | 0.667    |
# | rollout/Q_mean          | 0.834    |
# | rollout/actions_mean    | -0.0576  |
# | rollout/actions_std     | 0.629    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.58e+03 |
# | rollout/return          | 60.9     |
# | rollout/return_history  | 60.4     |
# | total/duration          | 755      |
# | total/episodes          | 2.58e+03 |
# | total/epochs            | 26       |
# | total/steps             | 260000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.26    |
# | train/loss_critic       | 0.174    |
# | train/param_noise_di... | 0.33     |
# --------------------------------------
#
# [26/2000] rSumAvg:[59.701]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 59.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0271   |
# | obs_rms_std             | 0.327    |
# | param_noise_stddev      | 0.0764   |
# | reference_Q_mean        | 1.17     |
# | reference_Q_std         | 0.461    |
# | reference_action_mean   | 0.122    |
# | reference_action_std    | 0.655    |
# | reference_actor_Q_mean  | 1.23     |
# | reference_actor_Q_std   | 0.416    |
# | reference_perturbed_... | 0.661    |
# | rollout/Q_mean          | 0.851    |
# | rollout/actions_mean    | -0.0508  |
# | rollout/actions_std     | 0.63     |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.68e+03 |
# | rollout/return          | 61       |
# | rollout/return_history  | 61.7     |
# | total/duration          | 784      |
# | total/episodes          | 2.68e+03 |
# | total/epochs            | 27       |
# | total/steps             | 270000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.31    |
# | train/loss_critic       | 0.167    |
# | train/param_noise_di... | 0.387    |
# --------------------------------------
# [27/2000] rSumAvg:[24.747]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 24.7     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.027    |
# | obs_rms_std             | 0.329    |
# | param_noise_stddev      | 0.0757   |
# | reference_Q_mean        | 1.17     |
# | reference_Q_std         | 0.481    |
# | reference_action_mean   | 0.114    |
# | reference_action_std    | 0.653    |
# | reference_actor_Q_mean  | 1.24     |
# | reference_actor_Q_std   | 0.434    |
# | reference_perturbed_... | 0.702    |
# | rollout/Q_mean          | 0.867    |
# | rollout/actions_mean    | -0.0451  |
# | rollout/actions_std     | 0.631    |
# | rollout/episode_steps   | 101      |
# | rollout/episodes        | 2.78e+03 |
# | rollout/return          | 61       |
# | rollout/return_history  | 61.5     |
# | total/duration          | 813      |
# | total/episodes          | 2.78e+03 |
# | total/epochs            | 28       |
# | total/steps             | 280000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.33    |
# | train/loss_critic       | 0.161    |
# | train/param_noise_di... | 0.492    |
# --------------------------------------
#
# [28/2000] rSumAvg:[65.857]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 65.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0268   |
# | obs_rms_std             | 0.331    |
# | param_noise_stddev      | 0.0749   |
# | reference_Q_mean        | 1.19     |
# | reference_Q_std         | 0.498    |
# | reference_action_mean   | 0.0968   |
# | reference_action_std    | 0.652    |
# | reference_actor_Q_mean  | 1.26     |
# | reference_actor_Q_std   | 0.45     |
# | reference_perturbed_... | 0.65     |
# | rollout/Q_mean          | 0.881    |
# | rollout/actions_mean    | -0.0406  |
# | rollout/actions_std     | 0.632    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 2.89e+03 |
# | rollout/return          | 60.7     |
# | rollout/return_history  | 51.4     |
# | total/duration          | 842      |
# | total/episodes          | 2.89e+03 |
# | total/epochs            | 29       |
# | total/steps             | 290000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.36    |
# | train/loss_critic       | 0.16     |
# | train/param_noise_di... | 0.455    |
# --------------------------------------
#
# [29/2000] rSumAvg:[58.778]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 58.8     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0267   |
# | obs_rms_std             | 0.333    |
# | param_noise_stddev      | 0.0742   |
# | reference_Q_mean        | 1.2      |
# | reference_Q_std         | 0.539    |
# | reference_action_mean   | 0.0823   |
# | reference_action_std    | 0.654    |
# | reference_actor_Q_mean  | 1.26     |
# | reference_actor_Q_std   | 0.492    |
# | reference_perturbed_... | 0.623    |
# | rollout/Q_mean          | 0.894    |
# | rollout/actions_mean    | -0.0367  |
# | rollout/actions_std     | 0.633    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 2.99e+03 |
# | rollout/return          | 60.3     |
# | rollout/return_history  | 51.2     |
# | total/duration          | 871      |
# | total/episodes          | 2.99e+03 |
# | total/epochs            | 30       |
# | total/steps             | 300000   |
# | total/steps_per_second  | 344      |
# | train/loss_actor        | -1.38    |
# | train/loss_critic       | 0.162    |
# | train/param_noise_di... | 0.323    |
# --------------------------------------
#
# [30/2000] rSumAvg:[32.848]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 32.8     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0266   |
# | obs_rms_std             | 0.335    |
# | param_noise_stddev      | 0.0735   |
# | reference_Q_mean        | 1.22     |
# | reference_Q_std         | 0.567    |
# | reference_action_mean   | 0.0582   |
# | reference_action_std    | 0.66     |
# | reference_actor_Q_mean  | 1.29     |
# | reference_actor_Q_std   | 0.519    |
# | reference_perturbed_... | 0.681    |
# | rollout/Q_mean          | 0.904    |
# | rollout/actions_mean    | -0.0341  |
# | rollout/actions_std     | 0.634    |
# | rollout/episode_steps   | 100      |
# | rollout/episodes        | 3.09e+03 |
# | rollout/return          | 59.7     |
# | rollout/return_history  | 42.4     |
# | total/duration          | 900      |
# | total/episodes          | 3.09e+03 |
# | total/epochs            | 31       |
# | total/steps             | 310000   |
# | total/steps_per_second  | 345      |
# | train/loss_actor        | -1.41    |
# ...
# | eval/return             | -43      |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0135   |
# | reference_Q_mean        | 6.05     |
# | reference_Q_std         | 3.74     |
# | reference_action_mean   | 0.0746   |
# | reference_action_std    | 0.822    |
# | reference_actor_Q_mean  | 6.34     |
# | reference_actor_Q_std   | 3.62     |
# | reference_perturbed_... | 0.812    |
# | rollout/Q_mean          | 2.51     |
# | rollout/actions_mean    | -0.0618  |
# | rollout/actions_std     | 0.777    |
# | rollout/episode_steps   | 95.1     |
# | rollout/episodes        | 2.22e+04 |
# | rollout/return          | 21.6     |
# | rollout/return_history  | -0.283   |
# | total/duration          | 6.45e+03 |
# | total/episodes          | 2.22e+04 |
# | total/epochs            | 211      |
# | total/steps             | 2110000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.27    |
# | train/loss_critic       | 0.848    |
# | train/param_noise_di... | 0.122    |
# --------------------------------------
#
# [211/2000] rSumAvg:[0.910]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 0.91     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0137   |
# | reference_Q_mean        | 5.94     |
# | reference_Q_std         | 3.94     |
# | reference_action_mean   | 0.09     |
# | reference_action_std    | 0.824    |
# | reference_actor_Q_mean  | 6.23     |
# | reference_actor_Q_std   | 3.84     |
# | reference_perturbed_... | 0.816    |
# | rollout/Q_mean          | 2.52     |
# | rollout/actions_mean    | -0.0621  |
# | rollout/actions_std     | 0.778    |
# | rollout/episode_steps   | 95.1     |
# | rollout/episodes        | 2.23e+04 |
# | rollout/return          | 21.5     |
# | rollout/return_history  | 11.3     |
# | total/duration          | 6.48e+03 |
# | total/episodes          | 2.23e+04 |
# | total/epochs            | 212      |
# | total/steps             | 2120000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.13    |
# | train/loss_critic       | 0.897    |
# | train/param_noise_di... | 0.0916   |
# --------------------------------------
#
# [212/2000] rSumAvg:[32.902]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 32.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0135   |
# | reference_Q_mean        | 6.1      |
# | reference_Q_std         | 3.85     |
# | reference_action_mean   | 0.0782   |
# | reference_action_std    | 0.827    |
# | reference_actor_Q_mean  | 6.37     |
# | reference_actor_Q_std   | 3.75     |
# | reference_perturbed_... | 0.82     |
# | rollout/Q_mean          | 2.53     |
# | rollout/actions_mean    | -0.0624  |
# | rollout/actions_std     | 0.778    |
# | rollout/episode_steps   | 95       |
# | rollout/episodes        | 2.24e+04 |
# | rollout/return          | 21.5     |
# | rollout/return_history  | 13.8     |
# | total/duration          | 6.51e+03 |
# | total/episodes          | 2.24e+04 |
# | total/epochs            | 213      |
# | total/steps             | 2130000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.01    |
# | train/loss_critic       | 0.812    |
# | train/param_noise_di... | 0.111    |
# --------------------------------------
#
# [213/2000] rSumAvg:[37.928]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 37.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0137   |
# | reference_Q_mean        | 6.19     |
# | reference_Q_std         | 3.89     |
# | reference_action_mean   | 0.0614   |
# | reference_action_std    | 0.827    |
# | reference_actor_Q_mean  | 6.45     |
# | reference_actor_Q_std   | 3.77     |
# | reference_perturbed_... | 0.832    |
# | rollout/Q_mean          | 2.53     |
# | rollout/actions_mean    | -0.0633  |
# | rollout/actions_std     | 0.779    |
# | rollout/episode_steps   | 95       |
# | rollout/episodes        | 2.25e+04 |
# | rollout/return          | 21.5     |
# | rollout/return_history  | 15.7     |
# | total/duration          | 6.54e+03 |
# | total/episodes          | 2.25e+04 |
# | total/epochs            | 214      |
# | total/steps             | 2140000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.35    |
# | train/loss_critic       | 0.848    |
# | train/param_noise_di... | 0.0856   |
# --------------------------------------
#
# [214/2000] rSumAvg:[2.755]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 2.76     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0135   |
# | reference_Q_mean        | 6.24     |
# | reference_Q_std         | 3.79     |
# | reference_action_mean   | 0.0866   |
# | reference_action_std    | 0.826    |
# | reference_actor_Q_mean  | 6.5      |
# | reference_actor_Q_std   | 3.68     |
# | reference_perturbed_... | 0.822    |
# | rollout/Q_mean          | 2.54     |
# | rollout/actions_mean    | -0.0643  |
# | rollout/actions_std     | 0.779    |
# | rollout/episode_steps   | 95       |
# | rollout/episodes        | 2.26e+04 |
# | rollout/return          | 21.4     |
# | rollout/return_history  | 17.2     |
# | total/duration          | 6.58e+03 |
# | total/episodes          | 2.26e+04 |
# | total/epochs            | 215      |
# | total/steps             | 2150000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.26    |
# | train/loss_critic       | 0.709    |
# | train/param_noise_di... | 0.104    |
# --------------------------------------
#
# [215/2000] rSumAvg:[-149.807]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | -150     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0134   |
# | reference_Q_mean        | 6.07     |
# | reference_Q_std         | 4.07     |
# | reference_action_mean   | 0.0864   |
# | reference_action_std    | 0.833    |
# | reference_actor_Q_mean  | 6.35     |
# | reference_actor_Q_std   | 3.96     |
# | reference_perturbed_... | 0.824    |
# | rollout/Q_mean          | 2.55     |
# | rollout/actions_mean    | -0.0651  |
# | rollout/actions_std     | 0.78     |
# | rollout/episode_steps   | 94.9     |
# | rollout/episodes        | 2.28e+04 |
# | rollout/return          | 21.4     |
# | rollout/return_history  | 12.1     |
# | total/duration          | 6.61e+03 |
# | total/episodes          | 2.28e+04 |
# | total/epochs            | 216      |
# | total/steps             | 2160000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.27    |
# | train/loss_critic       | 0.763    |
# | train/param_noise_di... | 0.102    |
# --------------------------------------
# [216/2000] rSumAvg:[-167.211]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | -167     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0218   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0133   |
# | reference_Q_mean        | 6.32     |
# | reference_Q_std         | 3.9      |
# | reference_action_mean   | 0.0859   |
# | reference_action_std    | 0.838    |
# | reference_actor_Q_mean  | 6.59     |
# | reference_actor_Q_std   | 3.79     |
# | reference_perturbed_... | 0.833    |
# | rollout/Q_mean          | 2.55     |
# | rollout/actions_mean    | -0.0657  |
# | rollout/actions_std     | 0.78     |
# | rollout/episode_steps   | 94.9     |
# | rollout/episodes        | 2.29e+04 |
# | rollout/return          | 21.2     |
# | rollout/return_history  | -3.74    |
# | total/duration          | 6.64e+03 |
# | total/episodes          | 2.29e+04 |
# | total/epochs            | 217      |
# | total/steps             | 2170000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.44    |
# | train/loss_critic       | 0.793    |
# | train/param_noise_di... | 0.12     |
# --------------------------------------
#
# [217/2000] rSumAvg:[19.594]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 19.6     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0219   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0134   |
# | reference_Q_mean        | 6.3      |
# | reference_Q_std         | 3.95     |
# | reference_action_mean   | 0.109    |
# | reference_action_std    | 0.839    |
# | reference_actor_Q_mean  | 6.57     |
# | reference_actor_Q_std   | 3.83     |
# | reference_perturbed_... | 0.847    |
# | rollout/Q_mean          | 2.54     |
# | rollout/actions_mean    | -0.0661  |
# | rollout/actions_std     | 0.781    |
# | rollout/episode_steps   | 94.8     |
# | rollout/episodes        | 2.3e+04  |
# | rollout/return          | 21       |
# | rollout/return_history  | -16.3    |
# | total/duration          | 6.68e+03 |
# | total/episodes          | 2.3e+04  |
# | total/epochs            | 218      |
# | total/steps             | 2180000  |
# | total/steps_per_second  | 327      |
# | train/loss_actor        | -4.4     |
# | train/loss_critic       | 0.862    |
# | train/param_noise_di... | 0.0865   |
# --------------------------------------
#
# [218/2000] rSumAvg:[56.435]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 56.4     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0219   |
# | obs_rms_std             | 0.384    |
# | param_noise_stddev      | 0.0133   |
# | reference_Q_mean        | 6.3      |
# | reference_Q_std         | 4.02     |
# | reference_action_mean   | 0.112    |
# | reference_action_std    | 0.838    |
# | reference_actor_Q_mean  | 6.57     |
# | reference_actor_Q_std   | 3.89     |
# | reference_perturbed_... | 0.833    |
# | rollout/Q_mean          | 2.55     |
# | rollout/actions_mean    | -0.0657  |
# | rollout/actions_std     | 0.781    |
# | rollout/episode_steps   | 94.6     |
# | rollout/episodes        | 2.31e+04 |
# | rollout/return          | 20.9     |
# | rollout/return_history  | 1.37     |
# | total/duration          | 6.71e+03 |
# | total/episodes          | 2.31e+04 |
# | total/epochs            | 219      |
# | total/steps             | 2190000  |
# | total/steps_per_second  | 326      |
# | train/loss_actor        | -4.57    |
# | train/loss_critic       | 0.774    |
# | train/param_noise_di... | 0.106    |
# --------------------------------------
#
# [219/2000] rSumAvg:[2.407]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 2.41     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0219   |
# | obs_rms_std             | 0.385    |
# | param_noise_stddev      | 0.0131   |
# | reference_Q_mean        | 6.2      |
# | reference_Q_std         | 4.19     |
# | reference_action_mean   | 0.118    |
# | reference_action_std    | 0.843    |
# | reference_actor_Q_mean  | 6.49     |
# | reference_actor_Q_std   | 4.08     |
# | reference_perturbed_... | 0.839    |
# | rollout/Q_mean          | 2.56     |
# | rollout/actions_mean    | -0.0652  |
# | rollout/actions_std     | 0.782    |
# | rollout/episode_steps   | 94.5     |
# | rollout/episodes        | 2.33e+04 |
# | rollout/return          | 20.9     |
# | rollout/return_history  | 22.1     |
# | total/duration          | 6.74e+03 |
# | total/episodes          | 2.33e+04 |
# | total/epochs            | 220      |
# | total/steps             | 2200000  |
# | total/steps_per_second  | 326      |
# | train/loss_actor        | -4.57    |
# | train/loss_critic       | 0.777    |
# | train/param_noise_di... | 0.118    |
# --------------------------------------
#
# [220/2000] rSumAvg:[35.822]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 35.8     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0219   |
# | obs_rms_std             | 0.385    |
# | param_noise_stddev      | 0.013    |
# | reference_Q_mean        | 6.14     |
# | reference_Q_std         | 4.23     |
# | reference_action_mean   | 0.121    |
# | reference_action_std    | 0.843    |
# | reference_actor_Q_mean  | 6.42     |
# | reference_actor_Q_std   | 4.13     |
# | reference_perturbed_... | 0.838    |
# | rollout/Q_mean          | 2.57     |
# | rollout/actions_mean    | -0.0647  |
# | rollout/actions_std     | 0.782    |
# | rollout/episode_steps   | 94.4     |
# | rollout/episodes        | 2.34e+04 |
# | rollout/return          | 20.8     |
# | rollout/return_history  | 6.71     |
# | total/duration          | 6.77e+03 |
# | total/episodes          | 2.34e+04 |
# | total/epochs            | 221      |
# | total/steps             | 2210000  |
# | total/steps_per_second  | 326      |
# | train/loss_actor        | -4.58    |
# | train/loss_critic       | 0.788    |
# | train/param_noise_di... | 0.105    |
# --------------------------------------
#
# [221/2000] rSumAvg:[37.863]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 37.9     |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0219   |
# | obs_rms_std             | 0.385    |
# | param_noise_stddev      | 0.0129   |
# | reference_Q_mean        | 6.27     |
# | reference_Q_std         | 4.11     |
# | reference_action_mean   | 0.0919   |
# | reference_action_std    | 0.839    |
# | reference_actor_Q_mean  | 6.54     |
# | reference_actor_Q_std   | 4.01     |
# | reference_perturbed_... | 0.841    |
# | rollout/Q_mean          | 2.58     |
# | rollout/actions_mean    | -0.0647  |
# | rollout/actions_std     | 0.782    |
# | rollout/episode_steps   | 94.3     |
# | rollout/episodes        | 2.35e+04 |
# | rollout/return          | 20.8     |
# | rollout/return_history  | 20.2     |
# | total/duration          | 6.81e+03 |
# | total/episodes          | 2.35e+04 |
# | total/epochs            | 222      |
# | total/steps             | 2220000  |
# | total/steps_per_second  | 326      |
# | train/loss_actor        | -4.66    |
# | train/loss_critic       | 0.808    |
# | train/param_noise_di... | 0.108    |
# --------------------------------------
#
# [222/2000] rSumAvg:[12.005]
# --------------------------------------
# | eval/Q                  | 0        |
# | eval/episodes           | 0        |
# | eval/return             | 12       |
# | eval/return_history     | 0        |
# | obs_rms_mean            | 0.0219   |
# | obs_rms_std             | 0.385    |
# | param_noise_stddev      | 0.0127   |
# | reference_Q_mean        | 6.42     |
# | reference_Q_std         | 4.01     |
# | reference_action_mean   | 0.0842   |
# | reference_action_std    | 0.836    |
# | reference_actor_Q_mean  | 6.69     |
# | reference_actor_Q_std   | 3.93     |
# | reference_perturbed_... | 0.842    |
# | rollout/Q_mean          | 2.59     |
# | rollout/actions_mean    | -0.0654  |
# | rollout/actions_std     | 0.783    |
# | rollout/episode_steps   | 94.4     |
# | rollout/episodes        | 2.36e+04 |
# | rollout/return          | 20.9     |
# | rollout/return_history  | 28.5     |
# | total/duration          | 6.84e+03 |
# | total/episodes          | 2.36e+04 |
# | total/epochs            | 223      |
# | total/steps             | 2230000  |
# | total/steps_per_second  | 326      |
# | train/loss_actor        | -4.66    |
# | train/loss_critic       | 0.706    |
# | train/param_noise_di... | 0.102    |
# --------------------------------------
# [223/2000] rSumAvg:[-3.433]

# %%
# !python -m baselines.ddpg_custom.main --env-id Ant-v2 --nb-epochs 2000 --gamma 0.999 --nb-epoch-cycles 1 --nb-rollout-steps 10000 --seed 1

# %%
# !python -m baselines.ddpg_custom.main --env-id Ant-v2 --nb-epochs 2000 --gamma 0.999 --nb-epoch-cycles 1 --nb-rollout-steps 10000 --seed 2

# %%
# !python -m baselines.ddpg_custom.main --env-id Ant-v2 --nb-epochs 2000 --gamma 0.999 --nb-epoch-cycles 1 --nb-rollout-steps 10000 --seed 3
